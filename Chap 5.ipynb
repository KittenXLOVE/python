# %% [markdown]
# # 商用程式設計
# ## 2021/05/07
# # Chap 5 函式(Function)

# %%
import math
a = float(input("輸入數字："))
print(a*a*math.pi)
# Out:
# 輸入數字：10.1
# 320.4738665926948

# %%
print(eval(input("輸入：")))#自動轉換資料型態，包括表達式
# Out:
# 輸入：5+5*5
# 30

# %%
import math
def function(i):#使用def定義function
  return i*i*math.pi
print(function(10))
# Out:
# 314.1592653589793
